# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(18)
#setting the seed for python random numbers
rn.seed(19)
#setting the seed for tensorflow
tf.set_random_seed(20)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
#from keras.applications.vgg16 import preprocess_input
#from keras.models import Sequential
#from keras.applications import VGG16 
#from keras.layers import Activation, Dense
import os


from keras.preprocessing.image import ImageDataGenerator

import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time
from keras.layers import Conv2D
from keras.regularizers import l2

NAME = "CNN-kaggel-dataset-50epochs-2dropout-4cov2d-x200-30%split-184_42_64-7x7-no-dense"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))




pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

pickle_in = open("X_test.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("y_test.pickle","rb")
y_test = pickle.load(pickle_in)

X_test = X_test/255.0


# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(y, num_classes=3)
y_test= keras.utils.to_categorical(y_test, num_classes=3)


model = Sequential()

model.add(Conv2D(560, (3, 3), activation ='relu', input_shape=(200, 200, 3), 
                 kernel_regularizer=l2(0.005 ), 
                 bias_regularizer=l2(0.005 )
                ))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(280, (3, 3), activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(140, (3, 3), activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Dropout(0.5))

model.add(Conv2D(70, (3, 3), activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.45))
model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))
model.add(MaxPool2D(pool_size=(2, 2)))
#model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(32, activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))
model.add(Dense(100, activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))
model.add(Dense(200, activation ='relu', kernel_regularizer=l2(0.005 ), bias_regularizer=l2(0.005 )))

#model.add(Dropout(0.2))
model.add(Dense(3, activation ='softmax'))


model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
#model.load_weights('weights_cnn_model4_11.h5')
#model.load_weights('weights_cnn_model5_1.h5')
#X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)

cb= ModelCheckpoint(filepath='weights_cnn_model5_1.h5',  verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

history=model.fit(X, 
                  one_hot_labels,
                  batch_size=10,
                  epochs=50,
                  validation_split=0.1,
                  shuffle=True,
                  callbacks=[cb]
                     )



score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)



#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# Train on 162 samples, validate on 18 samples
# Epoch 1/50
# 162/162 [==============================] - 8s 47ms/step - loss: 4.9397 - acc: 0.3642 - val_loss: 4.0713 - val_acc: 0.3889
#
# Epoch 00001: val_acc improved from -inf to 0.38889, saving model to weights_cnn_model5_1.h5
# Epoch 2/50
# 162/162 [==============================] - 4s 27ms/step - loss: 3.5913 - acc: 0.3889 - val_loss: 3.2215 - val_acc: 0.3333
#
# Epoch 00002: val_acc did not improve from 0.38889
# Epoch 3/50
# 162/162 [==============================] - 4s 27ms/step - loss: 2.9091 - acc: 0.3889 - val_loss: 2.7119 - val_acc: 0.3889
#
# Epoch 00003: val_acc did not improve from 0.38889
# Epoch 4/50
# 162/162 [==============================] - 5s 28ms/step - loss: 2.5254 - acc: 0.3951 - val_loss: 2.3863 - val_acc: 0.3333
#
# Epoch 00004: val_acc did not improve from 0.38889
# Epoch 5/50
# 162/162 [==============================] - 5s 28ms/step - loss: 2.2275 - acc: 0.4074 - val_loss: 2.1631 - val_acc: 0.3333
#
# Epoch 00005: val_acc did not improve from 0.38889
# Epoch 6/50
# 162/162 [==============================] - 5s 28ms/step - loss: 2.0596 - acc: 0.3889 - val_loss: 1.9859 - val_acc: 0.3889
#
# Epoch 00006: val_acc did not improve from 0.38889
# Epoch 7/50
# 162/162 [==============================] - 5s 29ms/step - loss: 1.8730 - acc: 0.3580 - val_loss: 1.8572 - val_acc: 0.3333
#
# Epoch 00007: val_acc did not improve from 0.38889
# Epoch 8/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.7754 - acc: 0.4074 - val_loss: 1.7632 - val_acc: 0.3333
#
# Epoch 00008: val_acc did not improve from 0.38889
# Epoch 9/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.6860 - acc: 0.3951 - val_loss: 1.6794 - val_acc: 0.3333
#
# Epoch 00009: val_acc did not improve from 0.38889
# Epoch 10/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.6135 - acc: 0.4259 - val_loss: 1.6064 - val_acc: 0.3333
#
# Epoch 00010: val_acc did not improve from 0.38889
# Epoch 11/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.5105 - acc: 0.4074 - val_loss: 1.5497 - val_acc: 0.3333
#
# Epoch 00011: val_acc did not improve from 0.38889
# Epoch 12/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.5095 - acc: 0.4506 - val_loss: 1.5073 - val_acc: 0.3333
#
# Epoch 00012: val_acc did not improve from 0.38889
# Epoch 13/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.4229 - acc: 0.4074 - val_loss: 1.4861 - val_acc: 0.3889
#
# Epoch 00013: val_acc did not improve from 0.38889
# Epoch 14/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.4192 - acc: 0.4012 - val_loss: 1.4308 - val_acc: 0.3333
#
# Epoch 00014: val_acc did not improve from 0.38889
# Epoch 15/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.3797 - acc: 0.4259 - val_loss: 1.4041 - val_acc: 0.3333
#
# Epoch 00015: val_acc did not improve from 0.38889
# Epoch 16/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.3526 - acc: 0.4321 - val_loss: 1.3749 - val_acc: 0.3333
#
# Epoch 00016: val_acc did not improve from 0.38889
# Epoch 17/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.2943 - acc: 0.4074 - val_loss: 1.3495 - val_acc: 0.3333
#
# Epoch 00017: val_acc did not improve from 0.38889
# Epoch 18/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.2740 - acc: 0.3951 - val_loss: 1.3242 - val_acc: 0.3333
#
# Epoch 00018: val_acc did not improve from 0.38889
# Epoch 19/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.2474 - acc: 0.4198 - val_loss: 1.2695 - val_acc: 0.3889
#
# Epoch 00019: val_acc did not improve from 0.38889
# Epoch 20/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.1820 - acc: 0.4259 - val_loss: 1.2643 - val_acc: 0.3889
#
# Epoch 00020: val_acc did not improve from 0.38889
# Epoch 21/50
# 162/162 [==============================] - 4s 27ms/step - loss: 1.1428 - acc: 0.4259 - val_loss: 1.1489 - val_acc: 0.5000
#
# Epoch 00021: val_acc improved from 0.38889 to 0.50000, saving model to weights_cnn_model5_1.h5
# Epoch 22/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.1093 - acc: 0.4815 - val_loss: 1.1958 - val_acc: 0.4444
#
# Epoch 00022: val_acc did not improve from 0.50000
# Epoch 23/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.1108 - acc: 0.4938 - val_loss: 1.1615 - val_acc: 0.4444
#
# Epoch 00023: val_acc did not improve from 0.50000
# Epoch 24/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.0665 - acc: 0.5432 - val_loss: 1.8548 - val_acc: 0.4444
#
# Epoch 00024: val_acc did not improve from 0.50000
# Epoch 25/50
# 162/162 [==============================] - 4s 28ms/step - loss: 1.2857 - acc: 0.3951 - val_loss: 1.1928 - val_acc: 0.3333
#
# Epoch 00025: val_acc did not improve from 0.50000
# Epoch 26/50
# 162/162 [==============================] - 4s 27ms/step - loss: 1.0937 - acc: 0.4074 - val_loss: 1.1416 - val_acc: 0.5000
#
# Epoch 00026: val_acc did not improve from 0.50000
# Epoch 27/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.0786 - acc: 0.5000 - val_loss: 1.0305 - val_acc: 0.5556
#
# Epoch 00027: val_acc improved from 0.50000 to 0.55556, saving model to weights_cnn_model5_1.h5
# Epoch 28/50
# 162/162 [==============================] - 5s 28ms/step - loss: 1.0188 - acc: 0.5123 - val_loss: 1.1487 - val_acc: 0.5556
#
# Epoch 00028: val_acc did not improve from 0.55556
# Epoch 29/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.9831 - acc: 0.5802 - val_loss: 1.0032 - val_acc: 0.6111
#
# Epoch 00029: val_acc improved from 0.55556 to 0.61111, saving model to weights_cnn_model5_1.h5
# Epoch 30/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.9604 - acc: 0.5370 - val_loss: 1.0773 - val_acc: 0.7222
#
# Epoch 00030: val_acc improved from 0.61111 to 0.72222, saving model to weights_cnn_model5_1.h5
# Epoch 31/50
# 162/162 [==============================] - 4s 27ms/step - loss: 1.0238 - acc: 0.5247 - val_loss: 0.9487 - val_acc: 0.6111
#
# Epoch 00031: val_acc did not improve from 0.72222
# Epoch 32/50
# 162/162 [==============================] - 5s 28ms/step - loss: 0.9719 - acc: 0.5926 - val_loss: 1.0424 - val_acc: 0.6667
#
# Epoch 00032: val_acc did not improve from 0.72222
# Epoch 33/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.9602 - acc: 0.5494 - val_loss: 1.0045 - val_acc: 0.6111
#
# Epoch 00033: val_acc did not improve from 0.72222
# Epoch 34/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.9519 - acc: 0.5494 - val_loss: 0.9520 - val_acc: 0.7222
#
# Epoch 00034: val_acc improved from 0.72222 to 0.72222, saving model to weights_cnn_model5_1.h5
# Epoch 35/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.9649 - acc: 0.5617 - val_loss: 1.0147 - val_acc: 0.5556
#
# Epoch 00035: val_acc did not improve from 0.72222
# Epoch 36/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.9402 - acc: 0.5679 - val_loss: 0.9895 - val_acc: 0.5556
#
# Epoch 00036: val_acc did not improve from 0.72222
# Epoch 37/50
# 162/162 [==============================] - 5s 28ms/step - loss: 0.9166 - acc: 0.5556 - val_loss: 0.9779 - val_acc: 0.6667
#
# Epoch 00037: val_acc did not improve from 0.72222
# Epoch 38/50
# 162/162 [==============================] - 5s 28ms/step - loss: 0.9592 - acc: 0.5247 - val_loss: 0.9660 - val_acc: 0.6111
#
# Epoch 00038: val_acc did not improve from 0.72222
# Epoch 39/50
# 162/162 [==============================] - 4s 28ms/step - loss: 0.9211 - acc: 0.5864 - val_loss: 0.9381 - val_acc: 0.7222
#
# Epoch 00039: val_acc did not improve from 0.72222
# Epoch 40/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.8959 - acc: 0.6049 - val_loss: 0.9013 - val_acc: 0.6111
#
# Epoch 00040: val_acc did not improve from 0.72222
# Epoch 41/50
# 162/162 [==============================] - 4s 28ms/step - loss: 0.8972 - acc: 0.5741 - val_loss: 0.8846 - val_acc: 0.5556
#
# Epoch 00041: val_acc did not improve from 0.72222
# Epoch 42/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.8925 - acc: 0.5741 - val_loss: 0.9900 - val_acc: 0.5000
#
# Epoch 00042: val_acc did not improve from 0.72222
# Epoch 43/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.8708 - acc: 0.6111 - val_loss: 1.0485 - val_acc: 0.6111
# Epoch 00043: val_acc did not improve from 0.72222
# Epoch 44/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.8909 - acc: 0.5864 - val_loss: 0.9794 - val_acc: 0.5556
#
# Epoch 00044: val_acc did not improve from 0.72222
# Epoch 45/50
# 162/162 [==============================] - 5s 28ms/step - loss: 0.8934 - acc: 0.5617 - val_loss: 0.9412 - val_acc: 0.6111
#
# Epoch 00045: val_acc did not improve from 0.72222
# Epoch 46/50
# 162/162 [==============================] - 5s 28ms/step - loss: 0.8641 - acc: 0.5556 - val_loss: 0.9796 - val_acc: 0.5000
#
# Epoch 00046: val_acc did not improve from 0.72222
# Epoch 47/50
# 162/162 [==============================] - 5s 28ms/step - loss: 0.8555 - acc: 0.6111 - val_loss: 1.0035 - val_acc: 0.5000
#
# Epoch 00047: val_acc did not improve from 0.72222
# Epoch 48/50
# 162/162 [==============================] - 5s 29ms/step - loss: 0.8666 - acc: 0.5864 - val_loss: 0.8639 - val_acc: 0.6667
#
# Epoch 00048: val_acc did not improve from 0.72222
# Epoch 49/50
# 162/162 [==============================] - 5s 29ms/step - loss: 0.8568 - acc: 0.5864 - val_loss: 0.9880 - val_acc: 0.5556
#
# Epoch 00049: val_acc did not improve from 0.72222
# Epoch 50/50
# 162/162 [==============================] - 5s 29ms/step - loss: 0.8343 - acc: 0.6049 - val_loss: 1.0257 - val_acc: 0.5000
#
# Epoch 00050: val_acc did not improve from 0.72222
# 20/20 [==============================] - 0s 10ms/step
# Test loss
# 0.686798632144928
# Test accuracy
# 0.8500000238418579
# roc_auc_score
# 0.9423092185592186
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# {0: 0.8645833333333334}
# {0: 0.8645833333333334, 1: 0.989010989010989}
# {0: 0.8645833333333334, 1: 0.989010989010989, 2: 0.9733333333333334}
