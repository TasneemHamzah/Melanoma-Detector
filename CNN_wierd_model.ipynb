# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(12)
#setting the seed for python random numbers
rn.seed(13)
#setting the seed for tensorflow
tf.set_random_seed(14)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
#from keras.applications.vgg16 import preprocess_input
#from keras.models import Sequential
#from keras.applications import VGG16 
#from keras.layers import Activation, Dense
import os


from keras.preprocessing.image import ImageDataGenerator

import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time


NAME = "CNN-kaggel-dataset-50epochs-2dropout-4cov2d-x200-30%split-184_42_64-7x7-no-dense"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))




pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

#X = X/255.0

pickle_in = open("X_test.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("y_test.pickle","rb")
y_test = pickle.load(pickle_in)

#X_test = X_test/255.0

# keras part .............

# Generate dummy data
#import numpy as np
#data = np.random.random((1000, 100))
#labels = np.random.randint(10, size=(1000, 1))

# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(y, num_classes=3)
y_test= keras.utils.to_categorical(y_test, num_classes=3)

# Train the model, iterating on the data in batches of 32 samples
#model.fit(data, one_hot_labels, epochs=10, batch_size=32)

#end keras part...........


model = Sequential()

model.add(Conv2D(560, (3, 3), activation ='relu', input_shape=(200, 200, 3)))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(280, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(140, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Dropout(0.1))

model.add(Conv2D(70, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(32, activation ='relu'))

model.add(Dropout(0.2))
model.add(Dense(3, activation ='softmax'))


model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
model.load_weights('weights_cnn_model2_6.h5')
#X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)

#cb = [ModelCheckpoint("weights.h5", save_best_only=True, save_weights_only=True)]
cb= ModelCheckpoint(filepath='weights_cnn_model2_7.h5',  verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

history=model.fit(X, 
                  one_hot_labels,
                  batch_size=10,
                  epochs=50,
                  validation_split=0.1,
                  shuffle=True,
                  callbacks=[cb]
                     )



score, acc=model.evaluate( X_test, y_test)
print(score)
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print(auc_value)

#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# Train on 162 samples, validate on 18 samples
# Epoch 1/50
# 162/162 [==============================] - 5s 28ms/step - loss: 2.3228 - acc: 0.6728 - val_loss: 0.0388 - val_acc: 1.0000
#
# Epoch 00001: val_acc improved from -inf to 1.00000, saving model to weights_cnn_model2_7.h5
# Epoch 2/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.9430 - acc: 0.7469 - val_loss: 0.1646 - val_acc: 1.0000
#
# Epoch 00002: val_acc did not improve from 1.00000
# Epoch 3/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.6461 - acc: 0.7346 - val_loss: 0.3681 - val_acc: 0.7778
#
# Epoch 00003: val_acc did not improve from 1.00000
# Epoch 4/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.4528 - acc: 0.8272 - val_loss: 0.0646 - val_acc: 1.0000
#
# Epoch 00004: val_acc did not improve from 1.00000
# Epoch 5/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4253 - acc: 0.8519 - val_loss: 0.0911 - val_acc: 1.0000
#
# Epoch 00005: val_acc did not improve from 1.00000
# Epoch 6/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.3465 - acc: 0.8704 - val_loss: 0.1162 - val_acc: 1.0000
#
# Epoch 00006: val_acc did not improve from 1.00000
# Epoch 7/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.3811 - acc: 0.8765 - val_loss: 0.2719 - val_acc: 0.8889
#
# Epoch 00007: val_acc did not improve from 1.00000
# Epoch 8/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.3764 - acc: 0.8333 - val_loss: 0.1767 - val_acc: 1.0000
#
# Epoch 00008: val_acc did not improve from 1.00000
# Epoch 9/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.2303 - acc: 0.9136 - val_loss: 0.0623 - val_acc: 1.0000
#
# Epoch 00009: val_acc did not improve from 1.00000
# Epoch 10/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.3442 - acc: 0.8765 - val_loss: 0.1305 - val_acc: 0.9444
#
# Epoch 00010: val_acc did not improve from 1.00000
# Epoch 11/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.3492 - acc: 0.8704 - val_loss: 0.1121 - val_acc: 0.9444
#
# Epoch 00011: val_acc did not improve from 1.00000
# Epoch 12/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.2026 - acc: 0.9198 - val_loss: 0.1841 - val_acc: 0.9444
#
# Epoch 00012: val_acc did not improve from 1.00000
# Epoch 13/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.2318 - acc: 0.9074 - val_loss: 0.1361 - val_acc: 0.9444
#
# Epoch 00013: val_acc did not improve from 1.00000
# Epoch 14/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1807 - acc: 0.9259 - val_loss: 0.1077 - val_acc: 0.9444
#
# Epoch 00014: val_acc did not improve from 1.00000
# Epoch 15/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.2068 - acc: 0.9259 - val_loss: 0.0736 - val_acc: 0.9444
#
# Epoch 00015: val_acc did not improve from 1.00000
# Epoch 16/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.1753 - acc: 0.9198 - val_loss: 0.0477 - val_acc: 1.0000
#
# Epoch 00016: val_acc did not improve from 1.00000
# Epoch 17/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1523 - acc: 0.9259 - val_loss: 0.0465 - val_acc: 1.0000
#
# Epoch 00017: val_acc did not improve from 1.00000
# Epoch 18/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1366 - acc: 0.9321 - val_loss: 0.1580 - val_acc: 0.8889
#
# Epoch 00018: val_acc did not improve from 1.00000
# Epoch 19/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1282 - acc: 0.9383 - val_loss: 0.0533 - val_acc: 1.0000
#
# Epoch 00019: val_acc did not improve from 1.00000
# Epoch 20/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1109 - acc: 0.9506 - val_loss: 0.2130 - val_acc: 0.8889
#
# Epoch 00020: val_acc did not improve from 1.00000
# Epoch 21/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1282 - acc: 0.9383 - val_loss: 0.0197 - val_acc: 1.0000
#
# Epoch 00021: val_acc did not improve from 1.00000
# Epoch 22/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1277 - acc: 0.9383 - val_loss: 0.0652 - val_acc: 1.0000
#
# Epoch 00022: val_acc did not improve from 1.00000
# Epoch 23/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.1201 - acc: 0.9630 - val_loss: 0.4599 - val_acc: 0.8889
#
# Epoch 00023: val_acc did not improve from 1.00000
# Epoch 24/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.1776 - acc: 0.9444 - val_loss: 0.1867 - val_acc: 0.8889
#
# Epoch 00024: val_acc did not improve from 1.00000
# Epoch 25/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.2009 - acc: 0.9383 - val_loss: 0.1615 - val_acc: 0.9444
#
# Epoch 00025: val_acc did not improve from 1.00000
# Epoch 26/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1221 - acc: 0.9630 - val_loss: 0.3728 - val_acc: 0.8889
#
# Epoch 00026: val_acc did not improve from 1.00000
# Epoch 27/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1846 - acc: 0.9506 - val_loss: 0.1777 - val_acc: 0.8889
#
# Epoch 00027: val_acc did not improve from 1.00000
# Epoch 28/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1479 - acc: 0.9383 - val_loss: 0.0518 - val_acc: 1.0000
#
# Epoch 00028: val_acc did not improve from 1.00000
# Epoch 29/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.1607 - acc: 0.9630 - val_loss: 0.0509 - val_acc: 1.0000
#
# Epoch 00029: val_acc did not improve from 1.00000
# Epoch 30/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1168 - acc: 0.9383 - val_loss: 0.0397 - val_acc: 1.0000
#
# Epoch 00030: val_acc did not improve from 1.00000
# Epoch 31/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1436 - acc: 0.9444 - val_loss: 0.0227 - val_acc: 1.0000
#
# Epoch 00031: val_acc did not improve from 1.00000
# Epoch 32/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1454 - acc: 0.9568 - val_loss: 0.0266 - val_acc: 1.0000
#
# Epoch 00032: val_acc did not improve from 1.00000
# Epoch 33/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0759 - acc: 0.9630 - val_loss: 0.0713 - val_acc: 0.9444
#
# Epoch 00033: val_acc did not improve from 1.00000
# Epoch 34/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0469 - acc: 0.9877 - val_loss: 0.1337 - val_acc: 0.9444
#
# Epoch 00034: val_acc did not improve from 1.00000
# Epoch 35/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0560 - acc: 0.9753 - val_loss: 0.0453 - val_acc: 1.0000
#
# Epoch 00035: val_acc did not improve from 1.00000
# Epoch 36/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1173 - acc: 0.9506 - val_loss: 0.0170 - val_acc: 1.0000
#
# Epoch 00036: val_acc did not improve from 1.00000
# Epoch 37/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0983 - acc: 0.9753 - val_loss: 0.0083 - val_acc: 1.0000
#
# Epoch 00037: val_acc did not improve from 1.00000
# Epoch 38/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0934 - acc: 0.9630 - val_loss: 0.0166 - val_acc: 1.0000
#
# Epoch 00038: val_acc did not improve from 1.00000
# Epoch 39/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0545 - acc: 0.9753 - val_loss: 0.0099 - val_acc: 1.0000
#
# Epoch 00039: val_acc did not improve from 1.00000
# Epoch 40/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0469 - acc: 0.9753 - val_loss: 0.0039 - val_acc: 1.0000
#
# Epoch 00040: val_acc did not improve from 1.00000
# Epoch 41/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0388 - acc: 0.9815 - val_loss: 0.0017 - val_acc: 1.0000
#
# Epoch 00041: val_acc did not improve from 1.00000
# Epoch 42/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1162 - acc: 0.9753 - val_loss: 0.0510 - val_acc: 0.9444
#
# Epoch 00042: val_acc did not improve from 1.00000
# Epoch 43/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.1398 - acc: 0.9568 - val_loss: 0.2884 - val_acc: 0.9444
#
# Epoch 00043: val_acc did not improve from 1.00000
# Epoch 44/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.2172 - acc: 0.9383 - val_loss: 0.3357 - val_acc: 0.8889
#
# Epoch 00044: val_acc did not improve from 1.00000
# Epoch 45/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0952 - acc: 0.9691 - val_loss: 0.1250 - val_acc: 0.9444
#
# Epoch 00045: val_acc did not improve from 1.00000
# Epoch 46/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0949 - acc: 0.9568 - val_loss: 0.4226 - val_acc: 0.9444
#
# Epoch 00046: val_acc did not improve from 1.00000
# Epoch 47/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0647 - acc: 0.9815 - val_loss: 0.2355 - val_acc: 0.9444
#
# Epoch 00047: val_acc did not improve from 1.00000
# Epoch 48/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0980 - acc: 0.9630 - val_loss: 0.2555 - val_acc: 0.9444
#
# Epoch 00048: val_acc did not improve from 1.00000
# Epoch 49/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0625 - acc: 0.9815 - val_loss: 0.1130 - val_acc: 0.9444
#
# Epoch 00049: val_acc did not improve from 1.00000
# Epoch 50/50
# 162/162 [==============================] - 4s 25ms/step - loss: 0.0864 - acc: 0.9630 - val_loss: 0.1053 - val_acc: 0.9444
#
# Epoch 00050: val_acc did not improve from 1.00000
# 20/20 [==============================] - 0s 8ms/step
# 0.36094996333122253
# 0.8500000238418579
# 0.9643238705738706
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# {0: 0.9479166666666666}
# {0: 0.9479166666666666, 1: 0.945054945054945}
# {0: 0.9479166666666666, 1: 0.945054945054945, 2: 1.0}

# %%
model.save('CNN_wierd_model.h5')
