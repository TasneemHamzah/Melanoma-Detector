# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(3)
#setting the seed for python random numbers
rn.seed(4)
#setting the seed for tensorflow
tf.set_random_seed(5)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
#from keras.applications.vgg16 import preprocess_input
#from keras.models import Sequential
#from keras.applications import VGG16 
#from keras.layers import Activation, Dense
import os


from keras.preprocessing.image import ImageDataGenerator

import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time


NAME = "CNN-kaggel-dataset-50epochs-2dropout-4cov2d-x200-30%split-184_42_64-7x7-no-dense"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))




pickle_in = open("X2.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y2.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

# keras part .............

# Generate dummy data
#import numpy as np
#data = np.random.random((1000, 100))
#labels = np.random.randint(10, size=(1000, 1))

# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(y, num_classes=3)

# Train the model, iterating on the data in batches of 32 samples
#model.fit(data, one_hot_labels, epochs=10, batch_size=32)

#end keras part...........


model = Sequential()

model.add(Conv2D(184, (5, 5), activation ='relu', input_shape=(200, 200, 3)))
model.add(MaxPool2D(pool_size=(4, 4)))


model.add(Conv2D(100, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(100, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation ='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation ='softmax'))

model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)

#history=model.fit(X, one_hot_labels, batch_size=32, epochs=50, validation_split=0.3,callbacks=[tensorboard])
#model.evaluate_
''''model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)

#cb = [ModelCheckpoint("weights.h5", save_best_only=True, save_weights_only=True)]
cb= ModelCheckpoint(filepath='weights_cnn.h5',  verbose=1, monitor='val_loss', save_best_only=True, save_weights_only=True)

history=model.fit(X_train, y_train,
                      batch_size=10,
                      epochs=70,
                      validation_split=0.1,
                      shuffle=True,
                      callbacks=[cb]
                     )'''

'''model.load_weights('weights_cnn6.h5')
score, acc=model.evaluate( X_test, y_test)
print(score)
print(acc)

score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)



model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)
model.load_weights('weights_cnn_best.h5')'''



model.load_weights('weights_cnn_best3.h5')

score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)

#cb = [ModelCheckpoint("weights.h5", save_best_only=True, save_weights_only=True)]
cb= ModelCheckpoint(filepath='weights_cnn_best4.h5',  verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

history=model.fit(X_train, y_train,
                      batch_size=10,
                      epochs=70,
                      validation_split=0.1,
                      shuffle=True,
                      callbacks=[cb]
                     )
                     
#model.load_weights('weights_cnn6.h5')

score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)


#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# 20/20 [==============================] - 0s 7ms/step
# Test loss
# 2.177096366882324
# Test accuracy
# 0.75
# roc_auc_score
# 0.8643353174603176
# Train on 162 samples, validate on 18 samples
# Epoch 1/70
# 162/162 [==============================] - 1s 7ms/step - loss: 0.0443 - acc: 0.9815 - val_loss: 2.1342 - val_acc: 0.6111
#
# Epoch 00001: val_acc improved from -inf to 0.61111, saving model to weights_cnn_best4.h5
# Epoch 2/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1125 - acc: 0.9630 - val_loss: 1.8881 - val_acc: 0.6111
#
# Epoch 00002: val_acc did not improve from 0.61111
# Epoch 3/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1034 - acc: 0.9630 - val_loss: 2.3803 - val_acc: 0.6111
#
# Epoch 00003: val_acc did not improve from 0.61111
# Epoch 4/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1263 - acc: 0.9691 - val_loss: 4.0791 - val_acc: 0.6111
#
# Epoch 00004: val_acc did not improve from 0.61111
# Epoch 5/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1168 - acc: 0.9444 - val_loss: 2.3218 - val_acc: 0.6111
#
# Epoch 00005: val_acc did not improve from 0.61111
# Epoch 6/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0786 - acc: 0.9630 - val_loss: 2.0162 - val_acc: 0.6111
#
# Epoch 00006: val_acc did not improve from 0.61111
# Epoch 7/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.2043 - acc: 0.9321 - val_loss: 2.4613 - val_acc: 0.5556
#
# Epoch 00007: val_acc did not improve from 0.61111
# Epoch 8/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1318 - acc: 0.9321 - val_loss: 2.4038 - val_acc: 0.6667
#
# Epoch 00008: val_acc improved from 0.61111 to 0.66667, saving model to weights_cnn_best4.h5
# Epoch 9/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0733 - acc: 0.9815 - val_loss: 2.6695 - val_acc: 0.5556
#
# Epoch 00009: val_acc did not improve from 0.66667
# Epoch 10/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0966 - acc: 0.9691 - val_loss: 2.0053 - val_acc: 0.6667
#
# Epoch 00010: val_acc did not improve from 0.66667
# Epoch 11/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0436 - acc: 0.9938 - val_loss: 2.2120 - val_acc: 0.6111
#
# Epoch 00011: val_acc did not improve from 0.66667
# Epoch 12/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0552 - acc: 0.9815 - val_loss: 2.6034 - val_acc: 0.6111
#
# Epoch 00012: val_acc did not improve from 0.66667
# Epoch 13/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0661 - acc: 0.9568 - val_loss: 2.8474 - val_acc: 0.6111
#
# Epoch 00013: val_acc did not improve from 0.66667
# Epoch 14/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0582 - acc: 0.9753 - val_loss: 2.9763 - val_acc: 0.5556
#
# Epoch 00014: val_acc did not improve from 0.66667
# Epoch 15/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1152 - acc: 0.9568 - val_loss: 2.5053 - val_acc: 0.6111
#
# Epoch 00015: val_acc did not improve from 0.66667
# Epoch 16/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1796 - acc: 0.9568 - val_loss: 1.8570 - val_acc: 0.6667
#
# Epoch 00016: val_acc did not improve from 0.66667
# Epoch 17/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0952 - acc: 0.9444 - val_loss: 2.1488 - val_acc: 0.5000
#
# Epoch 00017: val_acc did not improve from 0.66667
# Epoch 18/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1377 - acc: 0.9630 - val_loss: 1.5310 - val_acc: 0.5000
#
# Epoch 00018: val_acc did not improve from 0.66667
# Epoch 19/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1112 - acc: 0.9753 - val_loss: 2.7184 - val_acc: 0.5556
#
# Epoch 00019: val_acc did not improve from 0.66667
# Epoch 20/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1041 - acc: 0.9630 - val_loss: 2.8744 - val_acc: 0.3889
#
# Epoch 00020: val_acc did not improve from 0.66667
# Epoch 21/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0370 - acc: 0.9938 - val_loss: 2.3078 - val_acc: 0.4444
#
# Epoch 00021: val_acc did not improve from 0.66667
# Epoch 22/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0439 - acc: 0.9815 - val_loss: 2.3097 - val_acc: 0.5000
#
# Epoch 00022: val_acc did not improve from 0.66667
# Epoch 23/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0312 - acc: 0.9877 - val_loss: 2.6141 - val_acc: 0.5000
#
# Epoch 00023: val_acc did not improve from 0.66667
# Epoch 24/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0458 - acc: 0.9815 - val_loss: 2.7646 - val_acc: 0.6111
#
# Epoch 00024: val_acc did not improve from 0.66667
# Epoch 25/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0941 - acc: 0.9753 - val_loss: 3.0209 - val_acc: 0.5000
#
# Epoch 00025: val_acc did not improve from 0.66667
# Epoch 26/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1156 - acc: 0.9691 - val_loss: 2.3761 - val_acc: 0.5000
#
# Epoch 00026: val_acc did not improve from 0.66667
# Epoch 27/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1270 - acc: 0.9506 - val_loss: 1.8470 - val_acc: 0.5556
#
# Epoch 00027: val_acc did not improve from 0.66667
# Epoch 28/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0504 - acc: 0.9815 - val_loss: 2.3564 - val_acc: 0.6111
#
# Epoch 00028: val_acc did not improve from 0.66667
# Epoch 29/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0840 - acc: 0.9691 - val_loss: 2.6589 - val_acc: 0.5556
#
# Epoch 00029: val_acc did not improve from 0.66667
# Epoch 30/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0449 - acc: 0.9815 - val_loss: 2.1796 - val_acc: 0.6111
#
# Epoch 00030: val_acc did not improve from 0.66667
# Epoch 31/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0733 - acc: 0.9753 - val_loss: 2.1167 - val_acc: 0.5556
#
# Epoch 00031: val_acc did not improve from 0.66667
# Epoch 32/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0733 - acc: 0.9753 - val_loss: 2.1274 - val_acc: 0.6111
#
# Epoch 00032: val_acc did not improve from 0.66667
# Epoch 33/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0230 - acc: 0.9938 - val_loss: 2.2946 - val_acc: 0.6111
#
# Epoch 00033: val_acc did not improve from 0.66667
# Epoch 34/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0428 - acc: 0.9877 - val_loss: 2.3021 - val_acc: 0.6111
#
# Epoch 00034: val_acc did not improve from 0.66667
# Epoch 35/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0330 - acc: 0.9877 - val_loss: 2.5515 - val_acc: 0.6111
#
# Epoch 00035: val_acc did not improve from 0.66667
# Epoch 36/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0373 - acc: 0.9938 - val_loss: 2.8489 - val_acc: 0.5556
#
# Epoch 00036: val_acc did not improve from 0.66667
# Epoch 37/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0314 - acc: 0.9877 - val_loss: 3.2315 - val_acc: 0.3889
#
# Epoch 00037: val_acc did not improve from 0.66667
# Epoch 38/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0664 - acc: 0.9815 - val_loss: 2.7880 - val_acc: 0.5000
#
# Epoch 00038: val_acc did not improve from 0.66667
# Epoch 39/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0926 - acc: 0.9753 - val_loss: 2.9505 - val_acc: 0.5556
#
# Epoch 00039: val_acc did not improve from 0.66667
# Epoch 40/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.2614 - acc: 0.9383 - val_loss: 3.9720 - val_acc: 0.5000
#
# Epoch 00040: val_acc did not improve from 0.66667
# Epoch 41/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1502 - acc: 0.9259 - val_loss: 4.1831 - val_acc: 0.4444
#
# Epoch 00041: val_acc did not improve from 0.66667
# Epoch 42/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1689 - acc: 0.9136 - val_loss: 2.7915 - val_acc: 0.4444
#
# Epoch 00042: val_acc did not improve from 0.66667
# Epoch 43/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0978 - acc: 0.9753 - val_loss: 1.5817 - val_acc: 0.4444
#
# Epoch 00043: val_acc did not improve from 0.66667
# Epoch 44/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0579 - acc: 0.9877 - val_loss: 2.5675 - val_acc: 0.5556
#
# Epoch 00044: val_acc did not improve from 0.66667
# Epoch 45/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0774 - acc: 0.9753 - val_loss: 2.7432 - val_acc: 0.5556
#
# Epoch 00045: val_acc did not improve from 0.66667
# Epoch 46/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0969 - acc: 0.9753 - val_loss: 3.0370 - val_acc: 0.5556
#
# Epoch 00046: val_acc did not improve from 0.66667
# Epoch 47/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0645 - acc: 0.9815 - val_loss: 2.9756 - val_acc: 0.5556
#
# Epoch 00047: val_acc did not improve from 0.66667
# Epoch 48/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1067 - acc: 0.9691 - val_loss: 1.6802 - val_acc: 0.6111
#
# Epoch 00048: val_acc did not improve from 0.66667
# Epoch 49/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.2040 - acc: 0.9444 - val_loss: 2.7682 - val_acc: 0.5556
#
# Epoch 00049: val_acc did not improve from 0.66667
# Epoch 50/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.3375 - acc: 0.9136 - val_loss: 1.0948 - val_acc: 0.6667
#
# Epoch 00050: val_acc did not improve from 0.66667
# Epoch 51/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.2929 - acc: 0.8704 - val_loss: 1.6529 - val_acc: 0.6111
#
# Epoch 00051: val_acc did not improve from 0.66667
# Epoch 52/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1525 - acc: 0.9383 - val_loss: 1.8296 - val_acc: 0.6111
#
# Epoch 00052: val_acc did not improve from 0.66667
# Epoch 53/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1036 - acc: 0.9877 - val_loss: 1.5928 - val_acc: 0.6667
#
# Epoch 00053: val_acc did not improve from 0.66667
# Epoch 54/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0873 - acc: 0.9691 - val_loss: 1.3479 - val_acc: 0.7778
#
# Epoch 00054: val_acc improved from 0.66667 to 0.77778, saving model to weights_cnn_best4.h5
# Epoch 55/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1920 - acc: 0.9630 - val_loss: 1.8017 - val_acc: 0.5556
#
# Epoch 00055: val_acc did not improve from 0.77778
# Epoch 56/70
#  10/162 [>.............................] - ETA: 0s - loss: 0.0030 - acc: 1.0000
