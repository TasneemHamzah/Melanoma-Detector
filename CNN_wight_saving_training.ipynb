# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(3)
#setting the seed for python random numbers
rn.seed(4)
#setting the seed for tensorflow
tf.set_random_seed(5)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
#from keras.applications.vgg16 import preprocess_input
#from keras.models import Sequential
#from keras.applications import VGG16 
#from keras.layers import Activation, Dense
import os


from keras.preprocessing.image import ImageDataGenerator

import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time


NAME = "CNN-kaggel-dataset-50epochs-2dropout-4cov2d-x200-30%split-184_42_64-7x7-no-dense"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))




pickle_in = open("X2.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y2.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

# keras part .............

# Generate dummy data
#import numpy as np
#data = np.random.random((1000, 100))
#labels = np.random.randint(10, size=(1000, 1))

# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(y, num_classes=3)

# Train the model, iterating on the data in batches of 32 samples
#model.fit(data, one_hot_labels, epochs=10, batch_size=32)

#end keras part...........


model = Sequential()

model.add(Conv2D(184, (5, 5), activation ='relu', input_shape=(200, 200, 3)))
model.add(MaxPool2D(pool_size=(4, 4)))


model.add(Conv2D(100, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(100, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation ='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation ='softmax'))

model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)

#history=model.fit(X, one_hot_labels, batch_size=32, epochs=50, validation_split=0.3,callbacks=[tensorboard])
#model.evaluate_
''''model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)

#cb = [ModelCheckpoint("weights.h5", save_best_only=True, save_weights_only=True)]
cb= ModelCheckpoint(filepath='weights_cnn.h5',  verbose=1, monitor='val_loss', save_best_only=True, save_weights_only=True)

history=model.fit(X_train, y_train,
                      batch_size=10,
                      epochs=70,
                      validation_split=0.1,
                      shuffle=True,
                      callbacks=[cb]
                     )'''

'''model.load_weights('weights_cnn6.h5')
score, acc=model.evaluate( X_test, y_test)
print(score)
print(acc)

score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)



model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
X_train, X_test, y_train, y_test = train_test_split(X,one_hot_labels,test_size=0.1,shuffle=False)
model.load_weights('weights_cnn_best.h5')'''



model.load_weights('weights_cnn_best4.h5')
score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)

#cb = [ModelCheckpoint("weights.h5", save_best_only=True, save_weights_only=True)]
cb= ModelCheckpoint(filepath='weights_cnn_best5.h5',  verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

history=model.fit(X_train, y_train,
                      batch_size=10,
                      epochs=70,
                      validation_split=0.1,
                      shuffle=True,
                      callbacks=[cb]
                     )
                     
#model.load_weights('weights_cnn6.h5')

score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)


#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# 20/20 [==============================] - 0s 13ms/step
# Test loss
# 2.260159730911255
# Test accuracy
# 0.6499999761581421
# roc_auc_score
# 0.8374404761904762
# Train on 162 samples, validate on 18 samples
# Epoch 1/70
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0830 - acc: 0.9753 - val_loss: 1.5761 - val_acc: 0.6111
#
# Epoch 00001: val_acc improved from -inf to 0.61111, saving model to weights_cnn_best5.h5
# Epoch 2/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1052 - acc: 0.9568 - val_loss: 2.0369 - val_acc: 0.6111
#
# Epoch 00002: val_acc did not improve from 0.61111
# Epoch 3/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1406 - acc: 0.9630 - val_loss: 1.7355 - val_acc: 0.5556
#
# Epoch 00003: val_acc did not improve from 0.61111
# Epoch 4/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.2159 - acc: 0.9630 - val_loss: 2.8762 - val_acc: 0.6111
#
# Epoch 00004: val_acc improved from 0.61111 to 0.61111, saving model to weights_cnn_best5.h5
# Epoch 5/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1493 - acc: 0.9444 - val_loss: 2.4134 - val_acc: 0.5000
#
# Epoch 00005: val_acc did not improve from 0.61111
# Epoch 6/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0913 - acc: 0.9630 - val_loss: 1.8751 - val_acc: 0.5556
#
# Epoch 00006: val_acc did not improve from 0.61111
# Epoch 7/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1211 - acc: 0.9568 - val_loss: 1.9088 - val_acc: 0.6667
#
# Epoch 00007: val_acc improved from 0.61111 to 0.66667, saving model to weights_cnn_best5.h5
# Epoch 8/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1066 - acc: 0.9630 - val_loss: 1.6214 - val_acc: 0.6111
#
# Epoch 00008: val_acc did not improve from 0.66667
# Epoch 9/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0518 - acc: 0.9815 - val_loss: 1.9269 - val_acc: 0.6111
#
# Epoch 00009: val_acc did not improve from 0.66667
# Epoch 10/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0556 - acc: 0.9753 - val_loss: 2.0453 - val_acc: 0.6111
#
# Epoch 00010: val_acc did not improve from 0.66667
# Epoch 11/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0875 - acc: 0.9815 - val_loss: 2.0175 - val_acc: 0.5556
#
# Epoch 00011: val_acc did not improve from 0.66667
# Epoch 12/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0419 - acc: 0.9753 - val_loss: 1.8896 - val_acc: 0.5556
#
# Epoch 00012: val_acc did not improve from 0.66667
# Epoch 13/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0808 - acc: 0.9691 - val_loss: 2.1267 - val_acc: 0.5556
#
# Epoch 00013: val_acc did not improve from 0.66667
# Epoch 14/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0320 - acc: 0.9877 - val_loss: 2.6447 - val_acc: 0.6111
#
# Epoch 00014: val_acc did not improve from 0.66667
# Epoch 15/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0246 - acc: 1.0000 - val_loss: 2.5086 - val_acc: 0.6111
#
# Epoch 00015: val_acc did not improve from 0.66667
# Epoch 16/70
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0451 - acc: 0.9877 - val_loss: 2.9315 - val_acc: 0.5556
#
# Epoch 00016: val_acc did not improve from 0.66667
# Epoch 17/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0450 - acc: 0.9815 - val_loss: 2.9874 - val_acc: 0.5556
#
# Epoch 00017: val_acc did not improve from 0.66667
# Epoch 18/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0944 - acc: 0.9877 - val_loss: 2.4482 - val_acc: 0.5556
#
# Epoch 00018: val_acc did not improve from 0.66667
# Epoch 19/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0279 - acc: 0.9938 - val_loss: 2.7073 - val_acc: 0.6667
#
# Epoch 00019: val_acc did not improve from 0.66667
# Epoch 20/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0300 - acc: 0.9877 - val_loss: 2.9919 - val_acc: 0.6667
#
# Epoch 00020: val_acc did not improve from 0.66667
# Epoch 21/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0398 - acc: 0.9815 - val_loss: 3.3211 - val_acc: 0.5000
#
# Epoch 00021: val_acc did not improve from 0.66667
# Epoch 22/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1655 - acc: 0.9506 - val_loss: 2.8425 - val_acc: 0.5000
#
# Epoch 00022: val_acc did not improve from 0.66667
# Epoch 23/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1769 - acc: 0.9506 - val_loss: 2.8210 - val_acc: 0.6111
#
# Epoch 00023: val_acc did not improve from 0.66667
# Epoch 24/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0597 - acc: 0.9691 - val_loss: 3.3061 - val_acc: 0.6111
#
# Epoch 00024: val_acc did not improve from 0.66667
# Epoch 25/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0828 - acc: 0.9630 - val_loss: 3.7114 - val_acc: 0.5556
#
# Epoch 00025: val_acc did not improve from 0.66667
# Epoch 26/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1031 - acc: 0.9691 - val_loss: 3.1931 - val_acc: 0.3889
#
# Epoch 00026: val_acc did not improve from 0.66667
# Epoch 27/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1616 - acc: 0.9506 - val_loss: 2.5177 - val_acc: 0.6111
#
# Epoch 00027: val_acc did not improve from 0.66667
# Epoch 28/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0512 - acc: 0.9938 - val_loss: 2.9410 - val_acc: 0.5556
#
# Epoch 00028: val_acc did not improve from 0.66667
# Epoch 29/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1357 - acc: 0.9383 - val_loss: 2.1791 - val_acc: 0.5556
#
# Epoch 00029: val_acc did not improve from 0.66667
# Epoch 30/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0447 - acc: 0.9815 - val_loss: 2.4811 - val_acc: 0.6667
#
# Epoch 00030: val_acc did not improve from 0.66667
# Epoch 31/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1087 - acc: 0.9691 - val_loss: 1.9708 - val_acc: 0.5556
#
# Epoch 00031: val_acc did not improve from 0.66667
# Epoch 32/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1344 - acc: 0.9630 - val_loss: 2.3905 - val_acc: 0.5556
#
# Epoch 00032: val_acc did not improve from 0.66667
# Epoch 33/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1616 - acc: 0.9568 - val_loss: 2.1443 - val_acc: 0.4444
#
# Epoch 00033: val_acc did not improve from 0.66667
# Epoch 34/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1378 - acc: 0.9630 - val_loss: 3.0157 - val_acc: 0.5000
#
# Epoch 00034: val_acc did not improve from 0.66667
# Epoch 35/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0413 - acc: 0.9877 - val_loss: 2.9523 - val_acc: 0.5556
#
# Epoch 00035: val_acc did not improve from 0.66667
# Epoch 36/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0342 - acc: 0.9938 - val_loss: 2.9674 - val_acc: 0.5556
#
# Epoch 00036: val_acc did not improve from 0.66667
# Epoch 37/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0381 - acc: 0.9877 - val_loss: 3.4363 - val_acc: 0.4444
#
# Epoch 00037: val_acc did not improve from 0.66667
# Epoch 38/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0696 - acc: 0.9691 - val_loss: 3.0384 - val_acc: 0.5556
#
# Epoch 00038: val_acc did not improve from 0.66667
# Epoch 39/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0493 - acc: 0.9753 - val_loss: 2.6016 - val_acc: 0.6111
#
# Epoch 00039: val_acc did not improve from 0.66667
# Epoch 40/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0528 - acc: 0.9815 - val_loss: 2.7295 - val_acc: 0.5000
#
# Epoch 00040: val_acc did not improve from 0.66667
# Epoch 41/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0954 - acc: 0.9815 - val_loss: 2.4091 - val_acc: 0.5000
#
# Epoch 00041: val_acc did not improve from 0.66667
# Epoch 42/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0941 - acc: 0.9630 - val_loss: 2.2451 - val_acc: 0.6111
#
# Epoch 00042: val_acc did not improve from 0.66667
# Epoch 43/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0391 - acc: 0.9938 - val_loss: 2.5375 - val_acc: 0.5556
#
# Epoch 00043: val_acc did not improve from 0.66667
# Epoch 44/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0472 - acc: 0.9815 - val_loss: 2.5248 - val_acc: 0.6111
#
# Epoch 00044: val_acc did not improve from 0.66667
# Epoch 45/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0565 - acc: 0.9877 - val_loss: 2.5515 - val_acc: 0.5556
#
# Epoch 00045: val_acc did not improve from 0.66667
# Epoch 46/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0546 - acc: 0.9877 - val_loss: 2.6679 - val_acc: 0.5556
#
# Epoch 00046: val_acc did not improve from 0.66667
# Epoch 47/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0923 - acc: 0.9753 - val_loss: 2.8993 - val_acc: 0.5000
#
# Epoch 00047: val_acc did not improve from 0.66667
# Epoch 48/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0974 - acc: 0.9506 - val_loss: 2.1550 - val_acc: 0.5556
#
# Epoch 00048: val_acc did not improve from 0.66667
# Epoch 49/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0620 - acc: 0.9753 - val_loss: 1.6378 - val_acc: 0.6111
#
# Epoch 00049: val_acc did not improve from 0.66667
# Epoch 50/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0728 - acc: 0.9691 - val_loss: 2.1467 - val_acc: 0.5556
#
# Epoch 00050: val_acc did not improve from 0.66667
# Epoch 51/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0472 - acc: 0.9815 - val_loss: 2.6453 - val_acc: 0.5556
#
# Epoch 00051: val_acc did not improve from 0.66667
# Epoch 52/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0670 - acc: 0.9691 - val_loss: 1.6619 - val_acc: 0.5000
#
# Epoch 00052: val_acc did not improve from 0.66667
# Epoch 53/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0300 - acc: 0.9938 - val_loss: 2.2716 - val_acc: 0.5556
#
# Epoch 00053: val_acc did not improve from 0.66667
# Epoch 54/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0212 - acc: 0.9938 - val_loss: 2.1256 - val_acc: 0.6667
#
# Epoch 00054: val_acc did not improve from 0.66667
# Epoch 55/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0283 - acc: 0.9938 - val_loss: 2.4228 - val_acc: 0.6111
#
# Epoch 00055: val_acc did not improve from 0.66667
# Epoch 56/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0268 - acc: 0.9877 - val_loss: 2.5559 - val_acc: 0.5556
#
# Epoch 00056: val_acc did not improve from 0.66667
# Epoch 57/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0485 - acc: 0.9753 - val_loss: 2.3471 - val_acc: 0.6111
#
# Epoch 00057: val_acc did not improve from 0.66667
# Epoch 58/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0822 - acc: 0.9630 - val_loss: 2.4621 - val_acc: 0.6111
#
# Epoch 00058: val_acc did not improve from 0.66667
# Epoch 59/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0252 - acc: 0.9877 - val_loss: 2.8099 - val_acc: 0.5556
#
# Epoch 00059: val_acc did not improve from 0.66667
# Epoch 60/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0393 - acc: 0.9877 - val_loss: 2.4641 - val_acc: 0.6667
#
# Epoch 00060: val_acc did not improve from 0.66667
# Epoch 61/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0181 - acc: 1.0000 - val_loss: 2.5279 - val_acc: 0.6667
#
# Epoch 00061: val_acc did not improve from 0.66667
# Epoch 62/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0491 - acc: 0.9815 - val_loss: 3.0239 - val_acc: 0.6667
#
# Epoch 00062: val_acc did not improve from 0.66667
# Epoch 63/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0143 - acc: 0.9938 - val_loss: 3.2288 - val_acc: 0.6111
#
# Epoch 00063: val_acc did not improve from 0.66667
# Epoch 64/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0226 - acc: 0.9938 - val_loss: 3.2022 - val_acc: 0.6111
#
# Epoch 00064: val_acc did not improve from 0.66667
# Epoch 65/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0342 - acc: 0.9877 - val_loss: 2.8625 - val_acc: 0.6111
#
# Epoch 00065: val_acc did not improve from 0.66667
# Epoch 66/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0371 - acc: 0.9877 - val_loss: 3.0123 - val_acc: 0.6111
#
# Epoch 00066: val_acc did not improve from 0.66667
# Epoch 67/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0573 - acc: 0.9691 - val_loss: 3.5560 - val_acc: 0.5000
#
# Epoch 00067: val_acc did not improve from 0.66667
# Epoch 68/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0928 - acc: 0.9630 - val_loss: 2.3943 - val_acc: 0.5000
#
# Epoch 00068: val_acc did not improve from 0.66667
# Epoch 69/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.1087 - acc: 0.9815 - val_loss: 2.2110 - val_acc: 0.5556
#
# Epoch 00069: val_acc did not improve from 0.66667
# Epoch 70/70
# 162/162 [==============================] - 1s 4ms/step - loss: 0.0872 - acc: 0.9691 - val_loss: 1.9181 - val_acc: 0.6111
#
# Epoch 00070: val_acc did not improve from 0.66667
# 20/20 [==============================] - 0s 2ms/step
# Test loss
# 1.4581561088562012
# Test accuracy
# 0.800000011920929
# roc_auc_score
# 0.9001785714285715
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# {0: 0.83}
# {0: 0.83, 1: 0.9642857142857143}
# {0: 0.83, 1: 0.9642857142857143, 2: 0.90625}
