# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(12)
#setting the seed for python random numbers
rn.seed(13)
#setting the seed for tensorflow
tf.set_random_seed(14)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time




pickle_in = open("X_k.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y_k.pickle","rb")
y = pickle.load(pickle_in)

pickle_in = open("X_testk.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("y_testk.pickle","rb")
y_test = pickle.load(pickle_in)




# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(y, num_classes=3)
y_test= keras.utils.to_categorical(y_test, num_classes=3)



reg=keras.regularizers.l2(0.005)
#reg=keras.regularizers.l1_l2(l1=0.005, l2=0.005)
#reg=None


model = Sequential()

model.add(Conv2D(560, (3, 3), activation ='relu', input_shape=(200, 200, 3), kernel_regularizer=reg, 
                 bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(280, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(140, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Dropout(0.4))

model.add(Conv2D(70, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(32, activation ='relu'))

model.add(Dropout(0.4))
model.add(Dense(3, activation ='softmax'))


model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
#model.load_weights('wight_cnn_model_kaggel-3_std.h5')
#weights_cnn_model2_7.h5(kaggel)91test-train:(
#weights_cnn_model2_ph2_20%val.h5(94%acc)
#wight_cnn_model2_ph2_20%val989)
#wight_cnn_model_kaggel-2.h5
model.load_weights('wight_cnn_model_kaggel-4_std.h5')
cb= ModelCheckpoint(filepath='wight_cnn_model_kaggel-5_std.h5',  verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

history=model.fit(X, 
                  one_hot_labels,
                  batch_size=10,
                  epochs=50,
                  validation_split=0.1,
                  shuffle=True,
                  callbacks=[cb]
                     )



score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)

#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# Train on 1116 samples, validate on 124 samples
# Epoch 1/50
# 1116/1116 [==============================] - 29s 26ms/step - loss: 0.7667 - acc: 0.7088 - val_loss: 0.8828 - val_acc: 0.7258
#
# Epoch 00001: val_acc improved from -inf to 0.72581, saving model to wight_cnn_model_kaggel-5_std.h5
# Epoch 2/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7346 - acc: 0.7213 - val_loss: 0.9330 - val_acc: 0.6935
#
# Epoch 00002: val_acc did not improve from 0.72581
# Epoch 3/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7439 - acc: 0.7294 - val_loss: 0.9628 - val_acc: 0.6210
#
# Epoch 00003: val_acc did not improve from 0.72581
# Epoch 4/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6978 - acc: 0.7401 - val_loss: 0.9247 - val_acc: 0.6613
#
# Epoch 00004: val_acc did not improve from 0.72581
# Epoch 5/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7185 - acc: 0.7285 - val_loss: 0.9059 - val_acc: 0.6855
#
# Epoch 00005: val_acc did not improve from 0.72581
# Epoch 6/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6957 - acc: 0.7437 - val_loss: 0.8646 - val_acc: 0.6855
#
# Epoch 00006: val_acc did not improve from 0.72581
# Epoch 7/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7059 - acc: 0.7312 - val_loss: 0.8951 - val_acc: 0.6935
#
# Epoch 00007: val_acc did not improve from 0.72581
# Epoch 8/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7537 - acc: 0.7384 - val_loss: 0.9706 - val_acc: 0.6774
#
# Epoch 00008: val_acc did not improve from 0.72581
# Epoch 9/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7318 - acc: 0.7276 - val_loss: 0.9109 - val_acc: 0.6855
#
# Epoch 00009: val_acc did not improve from 0.72581
# Epoch 10/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7482 - acc: 0.7231 - val_loss: 0.9247 - val_acc: 0.6613
#
# Epoch 00010: val_acc did not improve from 0.72581
# Epoch 11/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7247 - acc: 0.7491 - val_loss: 0.8918 - val_acc: 0.6855
#
# Epoch 00011: val_acc did not improve from 0.72581
# Epoch 12/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7490 - acc: 0.7410 - val_loss: 0.9210 - val_acc: 0.6613
#
# Epoch 00012: val_acc did not improve from 0.72581
# Epoch 13/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7056 - acc: 0.7384 - val_loss: 0.8712 - val_acc: 0.6935
#
# Epoch 00013: val_acc did not improve from 0.72581
# Epoch 14/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6713 - acc: 0.7590 - val_loss: 0.8842 - val_acc: 0.7097
#
# Epoch 00014: val_acc did not improve from 0.72581
# Epoch 15/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6917 - acc: 0.7446 - val_loss: 0.9687 - val_acc: 0.6774
#
# Epoch 00015: val_acc did not improve from 0.72581
# Epoch 16/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6964 - acc: 0.7249 - val_loss: 0.9264 - val_acc: 0.6694
#
# Epoch 00016: val_acc did not improve from 0.72581
# Epoch 17/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7213 - acc: 0.7303 - val_loss: 0.9971 - val_acc: 0.5968
#
# Epoch 00017: val_acc did not improve from 0.72581
# Epoch 18/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7154 - acc: 0.7348 - val_loss: 0.9655 - val_acc: 0.6210
#
# Epoch 00018: val_acc did not improve from 0.72581
# Epoch 19/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.7070 - acc: 0.7491 - val_loss: 0.9713 - val_acc: 0.6371
#
# Epoch 00019: val_acc did not improve from 0.72581
# Epoch 20/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.7181 - acc: 0.7572 - val_loss: 0.9518 - val_acc: 0.6694
#
# Epoch 00020: val_acc did not improve from 0.72581
# Epoch 21/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7829 - acc: 0.7204 - val_loss: 1.0534 - val_acc: 0.6210
#
# Epoch 00021: val_acc did not improve from 0.72581
# Epoch 22/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7832 - acc: 0.7464 - val_loss: 0.9800 - val_acc: 0.6371
#
# Epoch 00022: val_acc did not improve from 0.72581
# Epoch 23/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6938 - acc: 0.7473 - val_loss: 1.0323 - val_acc: 0.6048
#
# Epoch 00023: val_acc did not improve from 0.72581
# Epoch 24/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6958 - acc: 0.7742 - val_loss: 0.9934 - val_acc: 0.6371
#
# Epoch 00024: val_acc did not improve from 0.72581
# Epoch 25/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6731 - acc: 0.7428 - val_loss: 1.0921 - val_acc: 0.5726
#
# Epoch 00025: val_acc did not improve from 0.72581
# Epoch 26/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6564 - acc: 0.7455 - val_loss: 0.9256 - val_acc: 0.6371
#
# Epoch 00026: val_acc did not improve from 0.72581
# Epoch 27/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6825 - acc: 0.7545 - val_loss: 1.0353 - val_acc: 0.5806
#
# Epoch 00027: val_acc did not improve from 0.72581
# Epoch 28/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6825 - acc: 0.7482 - val_loss: 0.9778 - val_acc: 0.6371
#
# Epoch 00028: val_acc did not improve from 0.72581
# Epoch 29/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7068 - acc: 0.7500 - val_loss: 0.9464 - val_acc: 0.6774
#
# Epoch 00029: val_acc did not improve from 0.72581
# Epoch 30/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7275 - acc: 0.7401 - val_loss: 1.0094 - val_acc: 0.6613
#
# Epoch 00030: val_acc did not improve from 0.72581
# Epoch 31/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6884 - acc: 0.7634 - val_loss: 0.9523 - val_acc: 0.6694
#
# Epoch 00031: val_acc did not improve from 0.72581
# Epoch 32/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6822 - acc: 0.7652 - val_loss: 0.9724 - val_acc: 0.6371
#
# Epoch 00032: val_acc did not improve from 0.72581
# Epoch 33/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6660 - acc: 0.7554 - val_loss: 0.9056 - val_acc: 0.6935
#
# Epoch 00033: val_acc did not improve from 0.72581
# Epoch 34/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6363 - acc: 0.7652 - val_loss: 0.9020 - val_acc: 0.7016
#
# Epoch 00034: val_acc did not improve from 0.72581
# Epoch 35/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6414 - acc: 0.7715 - val_loss: 0.9675 - val_acc: 0.6371
#
# Epoch 00035: val_acc did not improve from 0.72581
# Epoch 36/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6182 - acc: 0.7724 - val_loss: 0.9547 - val_acc: 0.6855
#
# Epoch 00036: val_acc did not improve from 0.72581
# Epoch 37/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6652 - acc: 0.7572 - val_loss: 0.9918 - val_acc: 0.6774
#
# Epoch 00037: val_acc did not improve from 0.72581
# Epoch 38/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6665 - acc: 0.7742 - val_loss: 1.0454 - val_acc: 0.5887
#
# Epoch 00038: val_acc did not improve from 0.72581
# Epoch 39/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6845 - acc: 0.7419 - val_loss: 0.9918 - val_acc: 0.6210
#
# Epoch 00039: val_acc did not improve from 0.72581
# Epoch 40/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6884 - acc: 0.7500 - val_loss: 0.9555 - val_acc: 0.6371
#
# Epoch 00040: val_acc did not improve from 0.72581
# Epoch 41/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6737 - acc: 0.7536 - val_loss: 1.0313 - val_acc: 0.6290
#
# Epoch 00041: val_acc did not improve from 0.72581
# Epoch 42/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6851 - acc: 0.7625 - val_loss: 0.9503 - val_acc: 0.6613
#
# Epoch 00042: val_acc did not improve from 0.72581
# Epoch 43/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.6768 - acc: 0.7581 - val_loss: 0.9635 - val_acc: 0.6613
#
# Epoch 00043: val_acc did not improve from 0.72581
# Epoch 44/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7013 - acc: 0.7527 - val_loss: 0.9437 - val_acc: 0.6613
#
# Epoch 00044: val_acc did not improve from 0.72581
# Epoch 45/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6643 - acc: 0.7572 - val_loss: 0.9216 - val_acc: 0.6613
#
# Epoch 00045: val_acc did not improve from 0.72581
# Epoch 46/50
# 1116/1116 [==============================] - 28s 25ms/step - loss: 0.7120 - acc: 0.7473 - val_loss: 0.9577 - val_acc: 0.6532
#
# Epoch 00046: val_acc did not improve from 0.72581
# Epoch 47/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6456 - acc: 0.7849 - val_loss: 0.9413 - val_acc: 0.6694
#
# Epoch 00047: val_acc did not improve from 0.72581
# Epoch 48/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.7199 - acc: 0.7473 - val_loss: 0.9944 - val_acc: 0.6694
#
# Epoch 00048: val_acc did not improve from 0.72581
# Epoch 49/50
# 1116/1116 [==============================] - 27s 25ms/step - loss: 0.6922 - acc: 0.7643 - val_loss: 1.0407 - val_acc: 0.6048
#
# Epoch 00049: val_acc did not improve from 0.72581
# Epoch 50/50
# 1116/1116 [==============================] - 27s 24ms/step - loss: 0.6499 - acc: 0.7724 - val_loss: 0.9369 - val_acc: 0.6613
#
# Epoch 00050: val_acc did not improve from 0.72581
# 368/368 [==============================] - 2s 7ms/step
# Test loss
# 0.7136671128480331
# Test accuracy
# 0.7771739130434783
# roc_auc_score
# 0.9109328940873228
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# {0: 0.9110508474576271}
# {0: 0.9110508474576271, 1: 0.9086140935456004}
# {0: 0.9110508474576271, 1: 0.9086140935456004, 2: 0.9131337412587412}

# %%
# create the confusion matrix

from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools 
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("confusion matrix of : ")
print(cm)

def plot_confusion_matrix(cm, classes,
                         normalize=False,
                         title='confusion matrix',
                         cmap=plt.cm.Reds):
    # this funcation print & plots confusion matrix
    # normalize can be applied by  normalize=True,
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks= np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm= cm.astype('float')/ cm.sum(axis=1)[:, np.newaxis]
        print("normalized confusion matrix")
    else:
        print(" confusion matrix, without normalized")
    print(cm)
    thresh=cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('true label')
    plt.xlabel('predicted label')

    '''input to confusion_matrix must be a list of predictions, not OHEs (one hot encodings). 
    Call argmax on your y_test and y_pred, and you should get what you expect.'''

from sklearn.utils.multiclass import unique_labels
classes = [1,2,3]
plot_confusion_matrix(cm,classes)
# Out:
# confusion matrix of :
# [[ 71  34  13]
#  [  7 128  11]
#  [  4  23  77]]
#  confusion matrix, without normalized
# [[ 71  34  13]
#  [  7 128  11]
#  [  4  23  77]]

# %%
model.save('kaggel_75acc.h5')
