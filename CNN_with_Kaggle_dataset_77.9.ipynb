# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(12)
#setting the seed for python random numbers
rn.seed(13)
#setting the seed for tensorflow
tf.set_random_seed(14)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time




pickle_in = open("X_k.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y_k.pickle","rb")
y = pickle.load(pickle_in)

pickle_in = open("X_testk.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("y_testk.pickle","rb")
y_test = pickle.load(pickle_in)




# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(y, num_classes=3)
y_test= keras.utils.to_categorical(y_test, num_classes=3)



reg=keras.regularizers.l2(0.005)
#reg=keras.regularizers.l1_l2(l1=0.005, l2=0.005)
#reg=None


model = Sequential()

model.add(Conv2D(560, (3, 3), activation ='relu', input_shape=(200, 200, 3), kernel_regularizer=reg, 
                 bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(280, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(140, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Dropout(0.4))

model.add(Conv2D(70, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(32, activation ='relu'))

model.add(Dropout(0.4))
model.add(Dense(3, activation ='softmax'))


model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
#model.load_weights('wight_cnn_model_kaggel-3_std.h5')
#weights_cnn_model2_7.h5(kaggel)91test-train:(
#weights_cnn_model2_ph2_20%val.h5(94%acc)
#wight_cnn_model2_ph2_20%val989)
#wight_cnn_model_kaggel-2.h5
#model.load_weights('wight_cnn_model_kaggel-4_std.h5')
model.load_weights('wight_cnn_model_kaggel-5_std.h5')
cb= ModelCheckpoint(filepath='wight_cnn_model_kaggel-6_std.h5',  verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

history=model.fit(X, 
                  one_hot_labels,
                  batch_size=10,
                  epochs=50,
                  validation_split=0.2,
                  shuffle=True,
                  callbacks=[cb]
                     )



score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)

#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# Train on 992 samples, validate on 248 samples
# Epoch 1/50
# 992/992 [==============================] - 29s 29ms/step - loss: 0.7096 - acc: 0.7450 - val_loss: 0.9396 - val_acc: 0.6734
#
# Epoch 00001: val_acc improved from -inf to 0.67339, saving model to wight_cnn_model_kaggel-6_std.h5
# Epoch 2/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7051 - acc: 0.7571 - val_loss: 0.9585 - val_acc: 0.6331
#
# Epoch 00002: val_acc did not improve from 0.67339
# Epoch 3/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7003 - acc: 0.7550 - val_loss: 0.9181 - val_acc: 0.6653
#
# Epoch 00003: val_acc did not improve from 0.67339
# Epoch 4/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6997 - acc: 0.7510 - val_loss: 0.8268 - val_acc: 0.7137
#
# Epoch 00004: val_acc improved from 0.67339 to 0.71371, saving model to wight_cnn_model_kaggel-6_std.h5
# Epoch 5/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6240 - acc: 0.7641 - val_loss: 0.8664 - val_acc: 0.7016
#
# Epoch 00005: val_acc did not improve from 0.71371
# Epoch 6/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6479 - acc: 0.7732 - val_loss: 0.8954 - val_acc: 0.6895
#
# Epoch 00006: val_acc did not improve from 0.71371
# Epoch 7/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7310 - acc: 0.7308 - val_loss: 1.5835 - val_acc: 0.5484
#
# Epoch 00007: val_acc did not improve from 0.71371
# Epoch 8/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7997 - acc: 0.7349 - val_loss: 0.9033 - val_acc: 0.7500
#
# Epoch 00008: val_acc improved from 0.71371 to 0.75000, saving model to wight_cnn_model_kaggel-6_std.h5
# Epoch 9/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7674 - acc: 0.7399 - val_loss: 0.8750 - val_acc: 0.7339
#
# Epoch 00009: val_acc did not improve from 0.75000
# Epoch 10/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6779 - acc: 0.7611 - val_loss: 0.8627 - val_acc: 0.6855
#
# Epoch 00010: val_acc did not improve from 0.75000
# Epoch 11/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6583 - acc: 0.7359 - val_loss: 0.8497 - val_acc: 0.7056
#
# Epoch 00011: val_acc did not improve from 0.75000
# Epoch 12/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6514 - acc: 0.7571 - val_loss: 0.8864 - val_acc: 0.7097
#
# Epoch 00012: val_acc did not improve from 0.75000
# Epoch 13/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6541 - acc: 0.7641 - val_loss: 0.9073 - val_acc: 0.6895
#
# Epoch 00013: val_acc did not improve from 0.75000
# Epoch 14/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6783 - acc: 0.7560 - val_loss: 0.9006 - val_acc: 0.6935
#
# Epoch 00014: val_acc did not improve from 0.75000
# Epoch 15/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6419 - acc: 0.7823 - val_loss: 1.0255 - val_acc: 0.6613
#
# Epoch 00015: val_acc did not improve from 0.75000
# Epoch 16/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6457 - acc: 0.7611 - val_loss: 0.8720 - val_acc: 0.6855
#
# Epoch 00016: val_acc did not improve from 0.75000
# Epoch 17/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6342 - acc: 0.7601 - val_loss: 0.9214 - val_acc: 0.6855
#
# Epoch 00017: val_acc did not improve from 0.75000
# Epoch 18/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6299 - acc: 0.7752 - val_loss: 0.8466 - val_acc: 0.6895
#
# Epoch 00018: val_acc did not improve from 0.75000
# Epoch 19/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6963 - acc: 0.7581 - val_loss: 0.9110 - val_acc: 0.6653
#
# Epoch 00019: val_acc did not improve from 0.75000
# Epoch 20/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7470 - acc: 0.7440 - val_loss: 0.8874 - val_acc: 0.6976
#
# Epoch 00020: val_acc did not improve from 0.75000
# Epoch 21/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6948 - acc: 0.7631 - val_loss: 0.9341 - val_acc: 0.6694
#
# Epoch 00021: val_acc did not improve from 0.75000
# Epoch 22/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.8495 - acc: 0.6976 - val_loss: 0.9959 - val_acc: 0.6815
#
# Epoch 00022: val_acc did not improve from 0.75000
# Epoch 23/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7517 - acc: 0.7591 - val_loss: 1.0268 - val_acc: 0.6774
#
# Epoch 00023: val_acc did not improve from 0.75000
# Epoch 24/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7066 - acc: 0.7470 - val_loss: 0.8457 - val_acc: 0.7056
#
# Epoch 00024: val_acc did not improve from 0.75000
# Epoch 25/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7493 - acc: 0.7329 - val_loss: 0.9639 - val_acc: 0.6411
#
# Epoch 00025: val_acc did not improve from 0.75000
# Epoch 26/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6996 - acc: 0.7520 - val_loss: 0.8942 - val_acc: 0.7016
#
# Epoch 00026: val_acc did not improve from 0.75000
# Epoch 27/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6709 - acc: 0.7601 - val_loss: 0.9170 - val_acc: 0.6411
#
# Epoch 00027: val_acc did not improve from 0.75000
# Epoch 28/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6806 - acc: 0.7540 - val_loss: 0.8291 - val_acc: 0.7016
#
# Epoch 00028: val_acc did not improve from 0.75000
# Epoch 29/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6882 - acc: 0.7530 - val_loss: 0.8508 - val_acc: 0.7056
#
# Epoch 00029: val_acc did not improve from 0.75000
# Epoch 30/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6828 - acc: 0.7500 - val_loss: 0.9058 - val_acc: 0.6532
#
# Epoch 00030: val_acc did not improve from 0.75000
# Epoch 31/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6604 - acc: 0.7611 - val_loss: 0.8801 - val_acc: 0.6734
#
# Epoch 00031: val_acc did not improve from 0.75000
# Epoch 32/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6743 - acc: 0.7550 - val_loss: 1.0157 - val_acc: 0.5968
#
# Epoch 00032: val_acc did not improve from 0.75000
# Epoch 33/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6610 - acc: 0.7692 - val_loss: 1.0210 - val_acc: 0.5847
#
# Epoch 00033: val_acc did not improve from 0.75000
# Epoch 34/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6511 - acc: 0.7671 - val_loss: 0.9419 - val_acc: 0.6613
#
# Epoch 00034: val_acc did not improve from 0.75000
# Epoch 35/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6416 - acc: 0.7712 - val_loss: 0.9310 - val_acc: 0.6774
#
# Epoch 00035: val_acc did not improve from 0.75000
# Epoch 36/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6439 - acc: 0.7661 - val_loss: 0.8667 - val_acc: 0.6855
#
# Epoch 00036: val_acc did not improve from 0.75000
# Epoch 37/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6471 - acc: 0.7651 - val_loss: 1.1996 - val_acc: 0.5403
#
# Epoch 00037: val_acc did not improve from 0.75000
# Epoch 38/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6642 - acc: 0.7641 - val_loss: 0.9258 - val_acc: 0.6734
#
# Epoch 00038: val_acc did not improve from 0.75000
# Epoch 39/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6627 - acc: 0.7681 - val_loss: 0.9225 - val_acc: 0.6613
#
# Epoch 00039: val_acc did not improve from 0.75000
# Epoch 40/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6843 - acc: 0.7732 - val_loss: 1.0135 - val_acc: 0.6048
#
# Epoch 00040: val_acc did not improve from 0.75000
# Epoch 41/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6835 - acc: 0.7571 - val_loss: 0.9837 - val_acc: 0.6653
#
# Epoch 00041: val_acc did not improve from 0.75000
# Epoch 42/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6941 - acc: 0.7792 - val_loss: 1.0088 - val_acc: 0.6210
#
# Epoch 00042: val_acc did not improve from 0.75000
# Epoch 43/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6776 - acc: 0.7621 - val_loss: 0.9128 - val_acc: 0.6694
#
# Epoch 00043: val_acc did not improve from 0.75000
# Epoch 44/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6291 - acc: 0.7762 - val_loss: 0.9355 - val_acc: 0.6774
#
# Epoch 00044: val_acc did not improve from 0.75000
# Epoch 45/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.5918 - acc: 0.7843 - val_loss: 0.9540 - val_acc: 0.6290
#
# Epoch 00045: val_acc did not improve from 0.75000
# Epoch 46/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.7085 - acc: 0.7369 - val_loss: 1.0255 - val_acc: 0.6048
#
# Epoch 00046: val_acc did not improve from 0.75000
# Epoch 47/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6944 - acc: 0.7510 - val_loss: 0.9941 - val_acc: 0.6331
#
# Epoch 00047: val_acc did not improve from 0.75000
# Epoch 48/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6883 - acc: 0.7681 - val_loss: 0.9570 - val_acc: 0.6492
#
# Epoch 00048: val_acc did not improve from 0.75000
# Epoch 49/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6565 - acc: 0.7692 - val_loss: 0.8928 - val_acc: 0.6734
#
# Epoch 00049: val_acc did not improve from 0.75000
# Epoch 50/50
# 992/992 [==============================] - 26s 26ms/step - loss: 0.6320 - acc: 0.7802 - val_loss: 0.8678 - val_acc: 0.7056
#
# Epoch 00050: val_acc did not improve from 0.75000
# 368/368 [==============================] - 3s 7ms/step
# Test loss
# 0.6637479844300643
# Test accuracy
# 0.779891304347826
# roc_auc_score
# 0.9227275537153061
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# {0: 0.927322033898305}
# {0: 0.927322033898305, 1: 0.9260150561520424}
# {0: 0.927322033898305, 1: 0.9260150561520424, 2: 0.9148455710955711}

# %%
# create the confusion matrix

from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools 
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("confusion matrix of : ")
print(cm)

def plot_confusion_matrix(cm, classes,
                         normalize=False,
                         title='confusion matrix',
                         cmap=plt.cm.Reds):
    # this funcation print & plots confusion matrix
    # normalize can be applied by  normalize=True,
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks= np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm= cm.astype('float')/ cm.sum(axis=1)[:, np.newaxis]
        print("normalized confusion matrix")
    else:
        print(" confusion matrix, without normalized")
    print(cm)
    thresh=cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('true label')
    plt.xlabel('predicted label')

    '''input to confusion_matrix must be a list of predictions, not OHEs (one hot encodings). 
    Call argmax on your y_test and y_pred, and you should get what you expect.'''

from sklearn.utils.multiclass import unique_labels
classes = [1,2,3]
plot_confusion_matrix(cm,classes)
# Out:
# confusion matrix of :
# [[ 81  24  13]
#  [  4 129  13]
#  [  8  19  77]]
#  confusion matrix, without normalized
# [[ 81  24  13]
#  [  4 129  13]
#  [  8  19  77]]

# %%
model.save('kaggel_77.9_no_overfittingacc.h5')
