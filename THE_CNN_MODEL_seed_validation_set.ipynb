# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)

import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED']='0'
#setting the seed nupy generator random number
np.random.seed(12)
#setting the seed for python random numbers
rn.seed(13)
#setting the seed for tensorflow
tf.set_random_seed(14)
from keras import backend as k

#force tensorflow to use a single thread
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
k.set_session(sess)


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pickle
from keras.callbacks import ModelCheckpoint
import sklearn
from sklearn.metrics import roc_curve, auc
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.callbacks import TensorBoard

import matplotlib.pyplot as plt
import time




pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

pickle_in = open("X_test.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("y_test.pickle","rb")
y_test = pickle.load(pickle_in)




# Convert labels to categorical one-hot encoding
Y = keras.utils.to_categorical(y, num_classes=3)
y_test= keras.utils.to_categorical(y_test, num_classes=3)


#from keras import regularizers
reg=keras.regularizers.l2(0.0005)
#reg=None

X_train_set=X[:54]  
y_train_set=Y[:54]
X_train_set2=X[72:180]
y_train_set2=Y[72:180]

X_trainig=np.concatenate([X_train_set,X_train_set2])
y_trainig=np.concatenate([y_train_set,y_train_set2])

X_val_set=X[54:72]
y_val_set=Y[54:72]









model = Sequential()

model.add(Conv2D(560, (3, 3), activation ='relu', input_shape=(200, 200, 3), kernel_regularizer=reg, 
                 bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(280, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(140, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(70, (3, 3), activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(32, (3, 3), strides = 1, activation ='relu', kernel_regularizer=reg, bias_regularizer=reg))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(32, activation ='relu'))
model.add(Dropout(0.4))
model.add(Dense(3, activation ='softmax'))

#combile the model
model.compile(loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          #shuffle=False
                          )
#loading the best model wights of previuos traing
#model.load_weights('weights_cnn_model2_6.h5')
model.load_weights('wight_cnn_model2_ph2_3_20%val_last.h5')
#save the best model wights
cb= ModelCheckpoint(filepath='wight_cnn_model2_ph2_4_20%val_last.h5',verbose=1, monitor='val_acc', save_best_only=True, save_weights_only=True)

#fit the model
history=model.fit(X_trainig, 
                  y_trainig,
                  batch_size=10,
                  epochs=50,
                  validation_data=(X_val_set,y_val_set),
                  shuffle=True,
                  callbacks=[cb]
                     )



score, acc=model.evaluate( X_test, y_test)
print('Test loss')
print(score)
print('Test accuracy')
print(acc)

y_pred = model.predict_proba(X_test)
auc_value=sklearn.metrics.roc_auc_score(y_test, y_pred)
print('roc_auc_score')
print(auc_value)

#score,acc=model.evaluate(X)

print(history.history.keys())

plt.plot(history.history['val_acc'])
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


'''def plot_ROC(y_test,y_pred):
    # Compute ROC curve and ROC area for each class
    #https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = {:.2f})'.format(roc_auc[i]))
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()'''
    
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        print(roc_auc)
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
for i in range(3):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = {:.2f})'.format(roc_auc[i]))
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic example')
        plt.legend(loc="lower right")
        plt.show()
# Out:
# Train on 162 samples, validate on 18 samples
# Epoch 1/50
# 162/162 [==============================] - 6s 38ms/step - loss: 0.3120 - acc: 0.9383 - val_loss: 0.3209 - val_acc: 0.8333
#
# Epoch 00001: val_acc improved from -inf to 0.83333, saving model to wight_cnn_model2_ph2_4_20%val_last.h5
# Epoch 2/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.7247 - acc: 0.8395 - val_loss: 0.4895 - val_acc: 0.7778
#
# Epoch 00002: val_acc did not improve from 0.83333
# Epoch 3/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.4485 - acc: 0.8580 - val_loss: 0.3673 - val_acc: 0.8889
#
# Epoch 00003: val_acc improved from 0.83333 to 0.88889, saving model to wight_cnn_model2_ph2_4_20%val_last.h5
# Epoch 4/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.5632 - acc: 0.8086 - val_loss: 0.4504 - val_acc: 0.9444
#
# Epoch 00004: val_acc improved from 0.88889 to 0.94444, saving model to wight_cnn_model2_ph2_4_20%val_last.h5
# Epoch 5/50
# 162/162 [==============================] - 4s 28ms/step - loss: 0.4758 - acc: 0.8272 - val_loss: 0.4254 - val_acc: 0.8333
#
# Epoch 00005: val_acc did not improve from 0.94444
# Epoch 6/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.5628 - acc: 0.8086 - val_loss: 0.4695 - val_acc: 0.7778
#
# Epoch 00006: val_acc did not improve from 0.94444
# Epoch 7/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.4686 - acc: 0.8210 - val_loss: 0.3321 - val_acc: 1.0000
#
# Epoch 00007: val_acc improved from 0.94444 to 1.00000, saving model to wight_cnn_model2_ph2_4_20%val_last.h5
# Epoch 8/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3831 - acc: 0.8704 - val_loss: 0.3937 - val_acc: 0.8889
#
# Epoch 00008: val_acc did not improve from 1.00000
# Epoch 9/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4614 - acc: 0.8580 - val_loss: 0.4155 - val_acc: 0.9444
#
# Epoch 00009: val_acc did not improve from 1.00000
# Epoch 10/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4155 - acc: 0.8642 - val_loss: 0.4477 - val_acc: 0.8333
#
# Epoch 00010: val_acc did not improve from 1.00000
# Epoch 11/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4610 - acc: 0.8148 - val_loss: 0.4377 - val_acc: 0.7778
#
# Epoch 00011: val_acc did not improve from 1.00000
# Epoch 12/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4832 - acc: 0.8395 - val_loss: 0.4125 - val_acc: 0.8889
#
# Epoch 00012: val_acc did not improve from 1.00000
# Epoch 13/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3968 - acc: 0.8642 - val_loss: 0.4632 - val_acc: 0.7778
#
# Epoch 00013: val_acc did not improve from 1.00000
# Epoch 14/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.5418 - acc: 0.8086 - val_loss: 0.4170 - val_acc: 0.9444
#
# Epoch 00014: val_acc did not improve from 1.00000
# Epoch 15/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3733 - acc: 0.8395 - val_loss: 0.4234 - val_acc: 0.8889
#
# Epoch 00015: val_acc did not improve from 1.00000
# Epoch 16/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.5360 - acc: 0.8395 - val_loss: 0.4239 - val_acc: 0.8333
#
# Epoch 00016: val_acc did not improve from 1.00000
# Epoch 17/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.3630 - acc: 0.8519 - val_loss: 0.3636 - val_acc: 0.9444
#
# Epoch 00017: val_acc did not improve from 1.00000
# Epoch 18/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.3801 - acc: 0.8827 - val_loss: 0.4618 - val_acc: 0.8333
#
# Epoch 00018: val_acc did not improve from 1.00000
# Epoch 19/50
# 162/162 [==============================] - 4s 27ms/step - loss: 0.4776 - acc: 0.7778 - val_loss: 0.4956 - val_acc: 0.7778
#
# Epoch 00019: val_acc did not improve from 1.00000
# Epoch 20/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3976 - acc: 0.8642 - val_loss: 0.4674 - val_acc: 0.8889
#
# Epoch 00020: val_acc did not improve from 1.00000
# Epoch 21/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4058 - acc: 0.8642 - val_loss: 0.4429 - val_acc: 0.8889
#
# Epoch 00021: val_acc did not improve from 1.00000
# Epoch 22/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3971 - acc: 0.8580 - val_loss: 0.4114 - val_acc: 0.8889
#
# Epoch 00022: val_acc did not improve from 1.00000
# Epoch 23/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4229 - acc: 0.8580 - val_loss: 0.4806 - val_acc: 0.8333
#
# Epoch 00023: val_acc did not improve from 1.00000
# Epoch 24/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4372 - acc: 0.8519 - val_loss: 0.4061 - val_acc: 0.8333
#
# Epoch 00024: val_acc did not improve from 1.00000
# Epoch 25/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3401 - acc: 0.8827 - val_loss: 0.3893 - val_acc: 0.8333
#
# Epoch 00025: val_acc did not improve from 1.00000
# Epoch 26/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4427 - acc: 0.8642 - val_loss: 0.5749 - val_acc: 0.7778
#
# Epoch 00026: val_acc did not improve from 1.00000
# Epoch 27/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3847 - acc: 0.8580 - val_loss: 0.4000 - val_acc: 0.8333
#
# Epoch 00027: val_acc did not improve from 1.00000
# Epoch 28/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4225 - acc: 0.8519 - val_loss: 0.4511 - val_acc: 0.8333
#
# Epoch 00028: val_acc did not improve from 1.00000
# Epoch 29/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3498 - acc: 0.8765 - val_loss: 0.4739 - val_acc: 0.7778
#
# Epoch 00029: val_acc did not improve from 1.00000
# Epoch 30/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3926 - acc: 0.8827 - val_loss: 0.6227 - val_acc: 0.7222
#
# Epoch 00030: val_acc did not improve from 1.00000
# Epoch 31/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4192 - acc: 0.8642 - val_loss: 0.7057 - val_acc: 0.8333
#
# Epoch 00031: val_acc did not improve from 1.00000
# Epoch 32/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4054 - acc: 0.8704 - val_loss: 0.5381 - val_acc: 0.7778
#
# Epoch 00032: val_acc did not improve from 1.00000
# Epoch 33/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3919 - acc: 0.8704 - val_loss: 0.4781 - val_acc: 0.8333
#
# Epoch 00033: val_acc did not improve from 1.00000
# Epoch 34/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3621 - acc: 0.8951 - val_loss: 0.4023 - val_acc: 0.8333
#
# Epoch 00034: val_acc did not improve from 1.00000
# Epoch 35/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4195 - acc: 0.8395 - val_loss: 0.5115 - val_acc: 0.7778
#
# Epoch 00035: val_acc did not improve from 1.00000
# Epoch 36/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3566 - acc: 0.8519 - val_loss: 0.4672 - val_acc: 0.8333
#
# Epoch 00036: val_acc did not improve from 1.00000
# Epoch 37/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3121 - acc: 0.8889 - val_loss: 0.5284 - val_acc: 0.8333
#
# Epoch 00037: val_acc did not improve from 1.00000
# Epoch 38/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4151 - acc: 0.8519 - val_loss: 0.4413 - val_acc: 0.8333
#
# Epoch 00038: val_acc did not improve from 1.00000
# Epoch 39/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3751 - acc: 0.8765 - val_loss: 0.4524 - val_acc: 0.8333
#
# Epoch 00039: val_acc did not improve from 1.00000
# Epoch 40/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3406 - acc: 0.8642 - val_loss: 0.4942 - val_acc: 0.8333
#
# Epoch 00040: val_acc did not improve from 1.00000
# Epoch 41/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.4109 - acc: 0.8765 - val_loss: 0.4048 - val_acc: 0.8333
#
# Epoch 00041: val_acc did not improve from 1.00000
# Epoch 42/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3277 - acc: 0.8704 - val_loss: 0.3927 - val_acc: 0.8333
#
# Epoch 00042: val_acc did not improve from 1.00000
# Epoch 43/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3379 - acc: 0.9012 - val_loss: 0.4166 - val_acc: 0.8333
#
# Epoch 00043: val_acc did not improve from 1.00000
# Epoch 44/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3419 - acc: 0.8889 - val_loss: 0.4935 - val_acc: 0.7778
#
# Epoch 00044: val_acc did not improve from 1.00000
# Epoch 45/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3210 - acc: 0.9136 - val_loss: 0.4498 - val_acc: 0.8333
#
# Epoch 00045: val_acc did not improve from 1.00000
# Epoch 46/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3355 - acc: 0.8951 - val_loss: 0.5710 - val_acc: 0.8333
#
# Epoch 00046: val_acc did not improve from 1.00000
# Epoch 47/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3279 - acc: 0.8889 - val_loss: 0.4936 - val_acc: 0.8333
#
# Epoch 00047: val_acc did not improve from 1.00000
# Epoch 48/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3736 - acc: 0.8951 - val_loss: 0.4287 - val_acc: 0.7778
#
# Epoch 00048: val_acc did not improve from 1.00000
# Epoch 49/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3383 - acc: 0.9012 - val_loss: 0.4193 - val_acc: 0.8333
#
# Epoch 00049: val_acc did not improve from 1.00000
# Epoch 50/50
# 162/162 [==============================] - 4s 26ms/step - loss: 0.3985 - acc: 0.8457 - val_loss: 0.4856 - val_acc: 0.7222
#
# Epoch 00050: val_acc did not improve from 1.00000
# 20/20 [==============================] - 0s 9ms/step
# Test loss
# 0.275380402803421
# Test accuracy
# 1.0
# roc_auc_score
# 0.9965277777777777
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# {0: 0.9895833333333333}
# {0: 0.9895833333333333, 1: 1.0}
# {0: 0.9895833333333333, 1: 1.0, 2: 1.0}

# %%
#model.save('CNN_wierd_model_kaggel_dataset.h5')91

#model.save('CNN_wierd_model_ph2_85.h5')

#model.save('CNN_wierd_model_ph2_20%val_94acc.h5')

# %%
#model.save('CNN_wierd_model_ph2_20%val_94acc_1_ROC.h5')
model.save('CNN_wierd_model_Kaggel_10%val_100%acc__99ROC.h5')

# %%
# create the confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools 
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("confusion matrix of : ")
print(cm)

def plot_confusion_matrix(cm, classes,
                         normalize=False,
                         title='confusion matrix',
                         cmap=plt.cm.Reds):
    # this funcation print & plots confusion matrix
    # normalize can be applied by  normalize=True,
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks= np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm= cm.astype('float')/ cm.sum(axis=1)[:, np.newaxis]
        print("normalized confusion matrix")
    else:
        print(" confusion matrix, without normalized")
    print(cm)
    thresh=cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Predicted label')
    plt.xlabel('True label')

    '''input to confusion_matrix must be a list of predictions, not OHEs (one hot encodings). 
    Call argmax on your y_test and y_pred, and you should get what you expect.'''

from sklearn.utils.multiclass import unique_labels
classes = [1,2,3]
plot_confusion_matrix(cm,classes)
# Out:
# confusion matrix of :
# [[8 0 0]
#  [0 7 0]
#  [0 0 5]]
#  confusion matrix, without normalized
# [[8 0 0]
#  [0 7 0]
#  [0 0 5]]

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_71 (Conv2D)           (None, 198, 198, 560)     15680
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 99, 99, 560)       0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 99, 99, 560)       0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 97, 97, 280)       1411480
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 48, 48, 280)       0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 48, 48, 280)       0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 46, 46, 140)       352940
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 23, 23, 140)       0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 23, 23, 140)       0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 21, 21, 70)        88270
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 10, 10, 70)        0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 10, 10, 70)        0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 8, 8, 32)          20192
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 32)                16416
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 1,905,077
# Trainable params: 1,905,077
# Non-trainable params: 0
# _________________________________________________________________
